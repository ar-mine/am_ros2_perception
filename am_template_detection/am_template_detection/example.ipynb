# %% [markdown]
# ### Package Import

# %%
import os
import cv2
import matplotlib.pyplot as plt
from am_template_detection.DTOIDModule import DTOIDModule

# %% [markdown]
# ### Define image and templates path

# %%
image_path = "/home/armine/Dataset_link/input/frame105.jpg"
templates_path = "/home/armine/Dataset_link/output"
image = plt.imread(image_path)
templates_list = os.listdir(templates_path)
template = plt.imread(os.path.join(templates_path, templates_list[0]))
plt.subplot(1,2,1)
plt.imshow(image)
plt.subplot(1,2,2)
plt.imshow(template)

# %% [markdown]
# ### Process and visualization

# %%
detector = DTOIDModule(template_dir=templates_path)
# Out:
#   0%|          | 0/36 [00:00<?, ?it/s]/home/armine/softwares/miniconda3/envs/LLM-IM/lib/python3.8/site-packages/torch/nn/functional.py:3509: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# /home/armine/softwares/miniconda3/envs/LLM-IM/lib/python3.8/site-packages/torch/nn/functional.py:3631: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn(
# 100%|██████████| 36/36 [00:00<00:00, 339.61it/s]

# %%
image = cv2.imread(image_path)
success, output_img, bbox, angel, score = detector.process(image, threshold=0.5)
plt.imshow(cv2.cvtColor(output_img, cv2.COLOR_BGR2RGB))

# %%
success, bbox, angel, score
# Out:
# (True, (581, 257, 1164, 617), -3.5830034013457017, 0.91296476)
